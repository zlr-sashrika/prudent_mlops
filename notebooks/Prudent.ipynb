# %% [markdown]
# # Problem statement

# %% [markdown]
# - Building a sentiment analysis model to analyse customer reviews and feedback for a hospitality company.
# - The model should be able to classify reviews as positive, negative or neutral

# %%
# %pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (2.19.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: keras>=3.5.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\gurucharan\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: setuptools in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\gurucharan\appdata\roaming\python\python310\site-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: packaging in c:\users\gurucharan\appdata\roaming\python\python310\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: optree in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: namex in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gurucharan\appdata\roaming\python\python310\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pandas matplotlib seaborn nltk wordcloud scikit-learn keras
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
#      --------------------------------------- 11.6/11.6 MB 32.8 MB/s eta 0:00:00
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp310-cp310-win_amd64.whl (8.1 MB)
#      ---------------------------------------- 8.1/8.1 MB 28.6 MB/s eta 0:00:00
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ---------------------------------------- 294.9/294.9 kB ? eta 0:00:00
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 24.1 MB/s eta 0:00:00
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp310-cp310-win_amd64.whl (299 kB)
#      ------------------------------------- 299.8/299.8 kB 19.3 MB/s eta 0:00:00
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp310-cp310-win_amd64.whl (11.1 MB)
#      --------------------------------------- 11.1/11.1 MB 36.4 MB/s eta 0:00:00
# Requirement already satisfied: keras in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (3.9.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gurucharan\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.1.3)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      ------------------------------------- 347.8/347.8 kB 21.1 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      ------------------------------------- 509.2/509.2 kB 16.1 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
#      ------------------------------------- 221.2/221.2 kB 13.2 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#      ---------------------------------------- 111.1/111.1 kB ? eta 0:00:00
# Collecting pillow>=8
#   Downloading pillow-11.2.1-cp310-cp310-win_amd64.whl (2.7 MB)
#      ---------------------------------------- 2.7/2.7 MB 28.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\gurucharan\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
#      ---------------------------------------- 71.9/71.9 kB ? eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.57.0-cp310-cp310-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 17.5 MB/s eta 0:00:00
# Collecting click
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      ---------------------------------------- 98.2/98.2 kB 5.5 MB/s eta 0:00:00
# Collecting regex>=2021.8.3
#   Downloading regex-2024.11.6-cp310-cp310-win_amd64.whl (274 kB)
#      ------------------------------------- 274.0/274.0 kB 16.5 MB/s eta 0:00:00
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB 4.3 MB/s eta 0:00:00
# Collecting joblib
#   Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
#      ---------------------------------------- 307.7/307.7 kB ? eta 0:00:00
# Collecting scipy>=1.6.0
#   Downloading scipy-1.15.2-cp310-cp310-win_amd64.whl (41.2 MB)
#      --------------------------------------- 41.2/41.2 MB 27.3 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: namex in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from keras) (0.0.9)
# Requirement already satisfied: rich in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from keras) (14.0.0)
# Requirement already satisfied: absl-py in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from keras) (2.2.2)
# Requirement already satisfied: optree in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from keras) (0.15.0)
# Requirement already satisfied: ml-dtypes in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from keras) (0.5.1)
# Requirement already satisfied: h5py in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from keras) (3.13.0)
# Requirement already satisfied: six>=1.5 in c:\users\gurucharan\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\users\gurucharan\appdata\roaming\python\python310\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\gurucharan\appdata\roaming\python\python310\site-packages (from optree->keras) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gurucharan\appdata\roaming\python\python310\site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gurucharan\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Installing collected packages: pytz, tzdata, tqdm, threadpoolctl, scipy, regex, pyparsing, pillow, kiwisolver, joblib, fonttools, cycler, contourpy, click, scikit-learn, pandas, nltk, matplotlib, wordcloud, seaborn
# Successfully installed click-8.1.8 contourpy-1.3.2 cycler-0.12.1 fonttools-4.57.0 joblib-1.5.0 kiwisolver-1.4.8 matplotlib-3.10.1 nltk-3.9.1 pandas-2.2.3 pillow-11.2.1 pyparsing-3.2.3 pytz-2025.2 regex-2024.11.6 scikit-learn-1.6.1 scipy-1.15.2 seaborn-0.13.2 threadpoolctl-3.6.0 tqdm-4.67.1 tzdata-2025.2 wordcloud-1.9.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
from nltk import WordNetLemmatizer
from wordcloud import WordCloud
import pickle
from nltk.corpus import stopwords,wordnet
from nltk.tokenize import word_tokenize,sent_tokenize
import sklearn
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense,SimpleRNN,LSTM,GRU,Embedding,InputLayer,Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,ConfusionMatrixDisplay
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.naive_bayes import  BernoulliNB,MultinomialNB,CategoricalNB

# %% [markdown]
# ## Data Collection

# %%
data_set = pd.read_csv(r"tripadvisor_hotel_reviews.csv")
data_set.head()
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# - Explore the Sentiment dataset to understand its structure, features, and size.

# %%
# Making a copy of the dataset so as not to change the original dataframe.
df = data_set.copy()
df.head()
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5

# %%
# checking shape of the dataset
df.shape
# Out:
# (20491, 2)

# %%
# checking information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20491 entries, 0 to 20490
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  20491 non-null  object
#  1   Rating  20491 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 320.3+ KB

# %%
# Checking if there are any duplicates present in the dataset
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# checking for any null values in the dataset.
df.isnull().sum()
# Out:
# Review    0
# Rating    0
# dtype: int64

# %% [markdown]
# #### About  dataset
# - The dataset contains two columns of review and rating
# - Review  - This reviews are provided based on the customers stay at that paticular hotel
# - Ratings - This ratings are given by the customers on the bases of there stay in the hotel

# %% [markdown]
# `we can see that the dataset doesnot contain any of the duplicate and null value.If there are any null value we can use imputation techniques for fill the null values and for duplicate we can remove them.`

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
target_class_count = df['Rating'].value_counts()
target_class_count
# Out:
# Rating
# 5    9054
# 4    6039
# 3    2184
# 2    1793
# 1    1421
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df,
                x='Rating',
              palette="pastel",
              order = df['Rating'].value_counts().index)
plt.title('Rating Distribution')
plt.show()
# Out:
# C:\Users\GuruCharan\AppData\Local\Temp\ipykernel_22356\2923175143.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,

# %%
plt.pie(df['Rating'].value_counts(), labels=df['Rating'].unique().tolist(), autopct='%1.1f%%')
plt.title('Rating Distribution in percentage')
plt.show()

# %% [markdown]
# ## Text Preprocessing:

# %% [markdown]
# `Because the data is uneven, there's a probability that the model we develop may lean toward positive reviews, which is why I'm using rating column 4 only rather than both 4 and 5 as positive reviews.`

# %%
df['Rating'].value_counts()
# Out:
# Rating
# 5    9054
# 4    6039
# 3    2184
# 2    1793
# 1    1421
# Name: count, dtype: int64

# %%
df = df[df['Rating'] != 5]
df['Rating'].value_counts()
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                                   Review  Rating
# 0      nice hotel expensive parking got good deal sta...       4
# 1      ok nothing special charge diamond member hilto...       2
# 2      nice rooms not 4* experience hotel monaco seat...       3
# 3      excellent staff, housekeeping quality hotel ch...       4
# 4      poor value stayed monaco seattle july, nice ho...       2
# ...                                                  ...     ...
# 11432  not impressed unfriendly staff checked asked h...       2
# 11433  great location price view hotel great quick pl...       4
# 11434  ok just looks nice modern outside, desk staff ...       2
# 11435  hotel theft ruined vacation hotel opened sept ...       1
# 11436  people talking, ca n't believe excellent ratin...       2
#
# [11437 rows x 2 columns]

# %% [markdown]
# - Preprocess reviews text by removing stop words, special characters, and URLs.
# - Tokenize and lemmatize words to prepare the text for sentiment analysis.

# %%
df.Review
# Out:
# 0        nice hotel expensive parking got good deal sta...
# 1        ok nothing special charge diamond member hilto...
# 2        nice rooms not 4* experience hotel monaco seat...
# 3        excellent staff, housekeeping quality hotel ch...
# 4        poor value stayed monaco seattle july, nice ho...
#                                ...
# 11432    not impressed unfriendly staff checked asked h...
# 11433    great location price view hotel great quick pl...
# 11434    ok just looks nice modern outside, desk staff ...
# 11435    hotel theft ruined vacation hotel opened sept ...
# 11436    people talking, ca n't believe excellent ratin...
# Name: Review, Length: 11437, dtype: object

# %%
df_review=df['Review']

# %%
#Checking whether the given data is in correct text formate or not by creating a custom function
def checking_data(data):
    case=' '.join(data).islower()
    html = data.apply(lambda x:True if re.findall("<.+?>",x)else False).sum()
    urls = data.apply(lambda x:True if re.findall("http[s]?://.+? +",x)else False).sum()
    unwanted_ = data.apply(lambda x:True if re.findall("[]()*\-.,@#$%^&0-9]",x)else False).sum()
    if case==False:
        print('not in lower case')
    if html>0:
        print('have html tags')
    if urls>0:
        print('have urls ')
    if unwanted_>0:
        print('having unwanted characters')
    else:
        print("Nothing to do with data.The data is clean now.")

# %%
checking_data(df_review)
# Out:
# not in lower case
# having unwanted characters

# %% [markdown]
# - As the data is not in lower case and having unwanted charters we need to make it into lower case and need to remove unwanted  characters

# %%
# creating a different funtion to make the dataset into lower case ,removing unwanted  charters and

# %%
def lowercase(x):
     return x.str.lower()

# %%
def unwanted_characters(x):
    x = x.apply(lambda x : re.sub("[^a-z\s]"," ",x))
    return x

# %%
# lemmatization is a techinque used to remove the stopwords present the reviews data(text data)
def lemmatization(x):
    list_stp = stopwords.words("english")
    wl = WordNetLemmatizer()
    def lemmatize_text(text):
        words = word_tokenize(text)
        lemmatized_words = [wl.lemmatize(word, pos="v") for word in words if word not in list_stp]
        return " ".join(lemmatized_words)
    return x.apply(lemmatize_text)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\GuruCharan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\GuruCharan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\GuruCharan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#creating a pipepline to preprocess the data 
preprocesser_pipeline = Pipeline([('Lowercase', FunctionTransformer(lowercase)),
                              ('Unwanted Characters', FunctionTransformer(unwanted_characters)),
                              ('Lemmatization',FunctionTransformer(lemmatization))])

# %%
final_reviews = preprocesser_pipeline.fit_transform(df['Review'])

# %%
checking_data(final_reviews)
# Out:
# Nothing to do with data.The data is clean now.

# %%
final_df = pd.concat([pd.DataFrame(final_reviews,columns= ['Review']),df['Rating']],axis=1)

# %%
final_df.sample(4)
# Out:
#                                                  Review  Rating
# 4238  fabulous stay pick hotel price location review...       4
# 4197  nice boyfriend vacation secrets june service n...       4
# 2650  picture perfect return week paris day trip bru...       4
# 6172  average hotel average price stay hotel prins h...       3

# %% [markdown]
# ### EDA after preprocessing the Data

# %%
positive_reviews= final_df[final_df['Rating'] == 4]['Review']
negative_reviews= final_df[final_df['Rating'] <= 2]['Review']
netural_reviews = final_df[final_df['Rating'] == 3]['Review']

# %%
wl = WordNetLemmatizer()

# %%
pos_rev = wl.lemmatize(' '.join(positive_reviews))
neg_rev = wl.lemmatize(' '.join(negative_reviews))
net_rev = wl.lemmatize(' '.join(netural_reviews))

# %% [markdown]
# ### By using word cloud we can generate the most common words appeared  in different reviews columns

# %%
#pass the entire single sting having all positive reviews
wc = WordCloud().generate(pos_rev)
plt.imshow(wc)
plt.show()

# %%
#pass the entire single sting having all negative_reviews
wc = WordCloud().generate(neg_rev)
plt.imshow(wc)
plt.show()

# %%
#pass the entire single sting having all netural_reviews
wc = WordCloud().generate(net_rev)
plt.imshow(wc)
plt.show()

# %%
final_df
# Out:
#                                                   Review  Rating
# 0      nice hotel expensive park get good deal stay h...       4
# 1      ok nothing special charge diamond member hilto...       2
# 2      nice room experience hotel monaco seattle good...       3
# 3      excellent staff housekeep quality hotel chock ...       4
# 4      poor value stay monaco seattle july nice hotel...       2
# ...                                                  ...     ...
# 11432  impress unfriendly staff check ask higher floo...       2
# 11433  great location price view hotel great quick pl...       4
# 11434  ok look nice modern outside desk staff n parti...       2
# 11435  hotel theft ruin vacation hotel open sept gues...       1
# 11436  people talk ca n believe excellent ratings hot...       2
#
# [11437 rows x 2 columns]

# %%
# Correct spelling and use vectorized operations
final_df.loc[final_df['Rating'] == 4, 'Rating'] = 'Positive'
final_df.loc[final_df['Rating'] == 3, 'Rating'] = 'Neutral'
final_df.loc[final_df['Rating'] == 2, 'Rating'] = 'Negative'
final_df.loc[final_df['Rating'] == 1, 'Rating'] = 'Negative'
# Out:
# C:\Users\GuruCharan\AppData\Local\Temp\ipykernel_22356\3815766103.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Positive' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[final_df['Rating'] == 4, 'Rating'] = 'Positive'

# %%
final_df
# Out:
#                                                   Review    Rating
# 0      nice hotel expensive park get good deal stay h...  Positive
# 1      ok nothing special charge diamond member hilto...  Negative
# 2      nice room experience hotel monaco seattle good...   Neutral
# 3      excellent staff housekeep quality hotel chock ...  Positive
# 4      poor value stay monaco seattle july nice hotel...  Negative
# ...                                                  ...       ...
# 11432  impress unfriendly staff check ask higher floo...  Negative
# 11433  great location price view hotel great quick pl...  Positive
# 11434  ok look nice modern outside desk staff n parti...  Negative
# 11435  hotel theft ruin vacation hotel open sept gues...  Negative
# 11436  people talk ca n believe excellent ratings hot...  Negative
#
# [11437 rows x 2 columns]

# %% [markdown]
# ## Feature Engineering

# %%
x_train,x_test,y_train,y_test = train_test_split(final_df['Review'],final_df['Rating'],random_state=30,test_size=0.2,stratify=final_df['Rating'])
x_train,x_cv,y_train,y_cv = train_test_split(x_train,y_train,random_state=30,test_size=0.2,stratify=y_train)

# %%
y_train.value_counts()
# Out:
# Rating
# Positive    3865
# Negative    2057
# Neutral     1397
# Name: count, dtype: int64

# %% [markdown]
# ### Checking No. of words in each sentence of Review column

# %%
sentence_length = []
for sent in final_df['Review']:
    sentence_length.append(len(word_tokenize(sent)))
final_df['sent_length'] = sentence_length
final_df.head()
# Out:
#                                               Review    Rating  sent_length
# 0  nice hotel expensive park get good deal stay h...  Positive           81
# 1  ok nothing special charge diamond member hilto...  Negative          232
# 2  nice room experience hotel monaco seattle good...   Neutral          202
# 3  excellent staff housekeep quality hotel chock ...  Positive           86
# 4  poor value stay monaco seattle july nice hotel...  Negative           44

# %%
max(final_df['sent_length'])
# Out:
# 1889

# %%
final_df['sent_length'].value_counts(ascending = True)
# Out:
# sent_length
# 742       1
# 598       1
# 1179      1
# 791       1
# 1396      1
#        ...
# 58      112
# 56      112
# 51      116
# 60      119
# 69      122
# Name: count, Length: 552, dtype: int64

# %%
np.quantile(final_df['sent_length'],0.95)
# Out:
# np.float64(283.0)

# %%
# Since 283 is the maximum sentence length in 95% of the data, we utilize that as the maximum length.
max_length = 283

# %%
le = LabelEncoder()
Y_train = le.fit_transform(y_train)
Y_test = le.transform(y_test)

# %%
Y_cv = le.transform(y_cv)

# %% [markdown]
# ### Tokenization, Vectorization & Padding Sequence

# %%
# Word tokenizer
sent_tk = Tokenizer(oov_token='None')

# %%
sent_tk.fit_on_texts(x_train)

# %%
# Total No. of Unique words in our dataset
vocab_len =len(sent_tk.word_counts)
vocab_len
# Out:
# 25524

# %%
# Putting all index/unique id of each words in a sequence according to the data
seque_xtrain = sent_tk.texts_to_sequences(x_train)
len(seque_xtrain)
# Out:
# 7319

# %%
seque_x_cv = sent_tk.texts_to_sequences(x_cv)
len(seque_x_cv)
# Out:
# 1830

# %%
# Padding the Sequence data to make the dimensionalty to 
final_x_train =  pad_sequences(seque_xtrain,maxlen=max_length)
final_x_train.shape
# Out:
# (7319, 283)

# %%
final_x_cv =  pad_sequences(seque_x_cv,maxlen=max_length)
final_x_cv.shape
# Out:
# (1830, 283)

# %% [markdown]
# ## Model Building (Neural Network)

# %%
# model = Sequential()
# model.add(InputLayer((283,)))
# # Embedding
# model.add(Embedding(25444,500))
# # LSTM Layer
# model.add(LSTM(20,activation='tanh'))
# model.add(Dense(10,activation="relu"))
# model.add(Dropout(0.5))
# # Output Layer
# model.add(Dense(3,activation="softmax"))

# %%
# # Summary of our model
# model.summary()

# %%
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# er = EarlyStopping(patience=3)

# %%
# trained_model = model.fit(final_x_train,Y_train,batch_size=15,epochs=20,validation_data=(final_x_cv,Y_cv),callbacks=[er])

# %%
# seque_xtest = sent_tk.texts_to_sequences(x_test)
# final_x_test =  pad_sequences(seque_xtest,maxlen=max_length)
# final_x_test.shape

# %%
# y_pred = model.predict(final_x_test)

# %%
# y_pred.shape

# %%
# Y_test.shape

# %%
# y_pred

# %%
# accuracy_score(Y_test,np.argmax(y_pred,axis=1))

# %%
# print(classification_report(Y_test,np.argmax(y_pred,axis=1)))

# %%
# model.save(r"C:\Users\Ranjith\OneDrive\Desktop\Prudent\LSTM.keras")

# %% [markdown]
# ## Using Machine Learning

# %%
#Model1
cv1=CountVectorizer()

# %%
fbow=cv1.fit_transform(x_train)

# %% [markdown]
# ### Using Bernoulli Naive Bayes with CountVectorizer

# %%
b =BernoulliNB(alpha = 0.1)
final_model=b.fit(fbow,y_train)
final_model.predict(cv1.transform(x_test))
accuracy_score((y_test),final_model.predict(cv1.transform(x_test)))
# Out:
# 0.6993006993006993

# %%
cm = confusion_matrix(y_test,final_model.predict(cv1.transform(x_test)))
i = ConfusionMatrixDisplay(cm,display_labels=b.classes_)
i.plot()
plt.show()

# %% [markdown]
# ### Using Multinomial Naive Bayes with CountVectorizer

# %%
mn =MultinomialNB(alpha = 0.1)
final_model1=mn.fit(fbow,y_train)
final_model1.predict(cv1.transform(x_test))
accuracy_score((y_test),final_model.predict(cv1.transform(x_test)))
# Out:
# 0.6993006993006993

# %%
cm = confusion_matrix(y_test,final_model1.predict(cv1.transform(x_test)))
i = ConfusionMatrixDisplay(cm,display_labels=b.classes_)
i.plot()
plt.show()

# %%
tf_idf = TfidfVectorizer()
fbow1 = tf_idf.fit_transform(x_train)

# %% [markdown]
# ### Using Bernoulli Naive Bayes with TfidfVectorizer

# %%
b =BernoulliNB(alpha = 0.1)
final_model=b.fit(fbow1,y_train)
final_model.predict(tf_idf.transform(x_test))
accuracy_score((y_test),final_model.predict(tf_idf.transform(x_test)))
# Out:
# 0.6993006993006993

# %% [markdown]
# ### Using Multinomial Naive Bayes with TfidfVectorizer

# %%
mn =MultinomialNB(alpha = 0.1)
final_model1=mn.fit(fbow1,y_train)
final_model1.predict(tf_idf.transform(x_test))
accuracy_score((y_test),final_model.predict(tf_idf.transform(x_test)))
# Out:
# 0.6993006993006993

# %%
# with open(r"C:\Users\Ranjith\OneDrive\Desktop\Prudent\BernoulliNB.pkl", "wb") as file:
#     pickle.dump(final_model, file)

# %%
x_test
# Out:
# 810      look shabby large hotel absolutely room servic...
# 4901     stay hotel nights week pros con pros away tour...
# 10355    ok hotel reserve platinum room upgrade suite n...
# 3712     great place price definitely right check iberv...
# 3245     surprise surprise good review hotel get locati...
#                                ...
# 2034     great recently take group people puerto rico s...
# 7625     worst inclusive resort punta cana resort worse...
# 6431     funky modern room great stay adrema room moder...
# 6821     location location stay nights wife sept great ...
# 2091     stay stay group people person ceiling bathroom...
# Name: Review, Length: 2288, dtype: object
